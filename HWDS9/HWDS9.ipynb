# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import fashion_mnist

# %% [markdown]
# ### Let's download and prepare our data:

# %%
(train_x, train_y), (test_x, test_y) = fashion_mnist.load_data()
train_x, test_x = train_x / 255.0, test_x / 255.0

# %% [markdown]
# ### We create a basic model:

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=20, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# c:\Users\sikan\AppData\Local\pypoetry\Cache\virtualenvs\datasience-ZD1DWEDm-py3.12\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6829 - loss: 0.8952 - val_accuracy: 0.8335 - val_loss: 0.4670
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8223 - loss: 0.4965 - val_accuracy: 0.8529 - val_loss: 0.4112
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8437 - loss: 0.4296 - val_accuracy: 0.8608 - val_loss: 0.3883
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8493 - loss: 0.4196 - val_accuracy: 0.8652 - val_loss: 0.3700
# Epoch 5/20
# ...

# %%
import matplotlib.pyplot as plt

# Accurancy graph
plt.plot(history.history['accuracy'], label='Accurancy on train data')
plt.plot(history.history['val_accuracy'], label='Accurancy on test data')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accurancy graph (Adam optimizer)')
plt.show()

# Loss graph
plt.plot(history.history['loss'], label='Accurancy on train data')
plt.plot(history.history['val_loss'], label='Accurancy on test data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss graph (Adam optimizer)')
plt.show()

# %% [markdown]
# ### Let's increase the number of layers of our neural network and determine the accuracy and loss.

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=20, batch_size=512, validation_split=0.2, verbose=1)
# Out:
# c:\Users\sikan\AppData\Local\pypoetry\Cache\virtualenvs\datasience-ZD1DWEDm-py3.12\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.6232 - loss: 1.0420 - val_accuracy: 0.8453 - val_loss: 0.4443
# Epoch 2/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8365 - loss: 0.4596 - val_accuracy: 0.8636 - val_loss: 0.3808
# Epoch 3/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8545 - loss: 0.3995 - val_accuracy: 0.8717 - val_loss: 0.3547
# Epoch 4/20
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8693 - loss: 0.3623 - val_accuracy: 0.8778 - val_loss: 0.3329
# Epoch 5/20
# ...

# %% [markdown]
# We can see that after increasing the number of layers, the accuracy of the neural network improved and eventually reached 91%.

# %%
# Accurancy graph
plt.plot(history.history['accuracy'], label='Accurancy on train data')
plt.plot(history.history['val_accuracy'], label='Accurancy on test data')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accurancy graph (Adam optimizer)')
plt.show()

# Loss graph
plt.plot(history.history['loss'], label='Accurancy on train data')
plt.plot(history.history['val_loss'], label='Accurancy on test data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss graph (Adam optimizer)')
plt.show()

# %% [markdown]
# ### Let's reduce the number of neurons on each layer and batch size:

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=20, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5956 - loss: 1.1686 - val_accuracy: 0.8323 - val_loss: 0.4680
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8145 - loss: 0.5347 - val_accuracy: 0.8463 - val_loss: 0.4179
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8371 - loss: 0.4675 - val_accuracy: 0.8630 - val_loss: 0.3867
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8517 - loss: 0.4211 - val_accuracy: 0.8646 - val_loss: 0.3757
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8564 - loss: 0.4025 - val_accuracy: 0.8751 - val_loss: 0.3542
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8646 - loss: 0.3884 - val_accuracy: 0.8724 - val_loss: 0.3491
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8694 - loss: 0.3701 - val_accuracy: 0.8762 - val_loss: 0.3430
# Epoch 8/20
# ...

# %% [markdown]
# We can see that the accuracy indicators have deteriorated a little compared to previous calculations.

# %% [markdown]
# ### Let's increase the number of epochs:

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='sigmoid'),
    layers.Dropout(0.2),
    layers.Dense(64, activation='sigmoid'),
    layers.Dropout(0.2),
    layers.Dense(32, activation='sigmoid'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=60, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3456 - loss: 1.8828 - val_accuracy: 0.7400 - val_loss: 0.8119
# Epoch 2/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7186 - loss: 0.8266 - val_accuracy: 0.8067 - val_loss: 0.5741
# Epoch 3/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7857 - loss: 0.6358 - val_accuracy: 0.8286 - val_loss: 0.5019
# Epoch 4/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8130 - loss: 0.5571 - val_accuracy: 0.8417 - val_loss: 0.4555
# Epoch 5/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8293 - loss: 0.5121 - val_accuracy: 0.8516 - val_loss: 0.4234
# Epoch 6/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8399 - loss: 0.4742 - val_accuracy: 0.8547 - val_loss: 0.4088
# Epoch 7/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8424 - loss: 0.4646 - val_accuracy: 0.8598 - val_loss: 0.3952
# Epoch 8/60
# ...

# %% [markdown]
# We see that as the number of epochs increases, the accuracy of our model slowly increases.

# %%
# Accurancy graph
plt.plot(history.history['accuracy'], label='Accurancy on train data')
plt.plot(history.history['val_accuracy'], label='Accurancy on test data')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accurancy graph (Adam optimizer)')
plt.show()

# Loss graph
plt.plot(history.history['loss'], label='Accurancy on train data')
plt.plot(history.history['val_loss'], label='Accurancy on test data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss graph (Adam optimizer)')
plt.show()

# %% [markdown]
# ### In the last example, we will change the optimizer from 'adam' to 'rmsprop'. We will also increase the number of epochs and use the 'early stop' regularization mechanism to prevent overtraining.

# %%
from tensorflow.keras.callbacks import EarlyStopping

model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='sigmoid'),
    layers.Dropout(0.2),
    layers.Dense(64, activation='sigmoid'),
    layers.Dropout(0.2),
    layers.Dense(32, activation='sigmoid'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='rmsprop',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_accuracy', patience=4, restore_best_weights=True)

history = model.fit(train_x, train_y, epochs=60, batch_size=128, validation_split=0.2, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3073 - loss: 1.9108 - val_accuracy: 0.6833 - val_loss: 0.9155
# Epoch 2/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6523 - loss: 0.9274 - val_accuracy: 0.7581 - val_loss: 0.6439
# Epoch 3/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7414 - loss: 0.7015 - val_accuracy: 0.7987 - val_loss: 0.5437
# Epoch 4/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7853 - loss: 0.6040 - val_accuracy: 0.8230 - val_loss: 0.4994
# Epoch 5/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8100 - loss: 0.5515 - val_accuracy: 0.8368 - val_loss: 0.4552
# Epoch 6/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8252 - loss: 0.5089 - val_accuracy: 0.8425 - val_loss: 0.4461
# Epoch 7/60
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8305 - loss: 0.4962 - val_accuracy: 0.8497 - val_loss: 0.4300
# Epoch 8/60
# ...

# %% [markdown]
# The early-stopping mechanism worked, determining the exact accuracy before passing all epochs, but the performance is lower than that of the other optimizer.

# %%
# Accurancy graph
plt.plot(history.history['accuracy'], label='Accurancy on train data')
plt.plot(history.history['val_accuracy'], label='Accurancy on test data')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accurancy graph (Adam optimizer)')
plt.show()

# Loss graph
plt.plot(history.history['loss'], label='Accurancy on train data')
plt.plot(history.history['val_loss'], label='Accurancy on test data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss graph (Adam optimizer)')
plt.show()

# %% [markdown]
# ### So, we obtained the best accuracy rates (91.5%) with the following parameters: optimizer adam, number of layers 5, batch size 512, number of epochs 20.
